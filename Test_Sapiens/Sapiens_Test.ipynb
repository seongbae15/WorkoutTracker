# %% [markdown]
# # Installation: Lite Version

# %%
# !git clone https://github.com/facebookresearch/sapiens.git
# Out:
# Cloning into 'sapiens'...
# remote: Enumerating objects: 4977, done.
# remote: Counting objects: 100% (224/224), done.
# remote: Compressing objects: 100% (121/121), done.
# remote: Total 4977 (delta 154), reused 103 (delta 103), pack-reused 4753 (from 2)
# Receiving objects: 100% (4977/4977), 286.68 MiB | 35.25 MiB/s, done.
# Resolving deltas: 100% (1875/1875), done.
# Updating files: 100% (4466/4466), done.

# %%
# %cd sapiens
# Out:
# /content/sapiens

# %%
# %pwd
# Out:
# '/content/sapiens'

# %%
# !export SAPIENS_LITE_ROOT=/content/sapiens/lite

# %% [markdown]
# ## Download ckpts

# %%
# Make Dir
# !mkdir -p /content/sapiens/pose/checkpoints/sapiens_0.3b

# %%
# %cd ./pose/checkpoints/sapiens_0.3b
# Out:
# /content/sapiens/pose/checkpoints/sapiens_0.3b

# %%
# !git lfs install
# Out:
# Updated git hooks.
# Git LFS initialized.

# %%
# !git clone https://huggingface.co/facebook/sapiens-pose-0.3b-torchscript
# Out:
# Cloning into 'sapiens-pose-0.3b-torchscript'...
# remote: Enumerating objects: 28, done.
# remote: Counting objects: 100% (22/22), done.
# remote: Compressing objects: 100% (22/22), done.
# remote: Total 28 (delta 9), reused 0 (delta 0), pack-reused 6 (from 1)
# Unpacking objects: 100% (28/28), 10.98 KiB | 1.57 MiB/s, done.

# %%
# %cd ../../../
# Out:
# /content/sapiens/pose

# %% [markdown]
# ## Install library

# %%
# !pip install json-tricks

# %%
# %cd engine/
# Out:
# /content/sapiens/engine

# %%
# !pip install -e .
# Out:
# Obtaining file:///content/sapiens/engine
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 13.1 MB/s eta 0:00:00
# ...
#   Running setup.py develop for sapiens_engine
# ...

# %%
# %cd ..
# Out:
# /content/sapiens

# %%
# %cd cv/
# !pip install -e .
# %cd ..
# Out:
# /content/sapiens/cv
# Obtaining file:///content/sapiens/cv
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for sapiens_cv
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/commands/install.py", line 455, in run
#     installed = install_given_reqs(
#                 ^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/req/__init__.py", line 70, in install_given_reqs
#     requirement.install(
#   File "/usr/local/lib/python3.11/dist-packages/pip/_internal/req/req_install.py", line 834, in install
# ...

# %%
# %cd det/
# !pip install -e .
# %cd ..
# Out:
# /content/sapiens/det
# Obtaining file:///content/sapiens/det
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for sapiens_det
# ...
# /content/sapiens

# %% [markdown]
# # Inference Test

# %%
# %cd ./pose
# Out:
# /content/sapiens/pose

# %%
# !mkdir -p output/vis/itw_videos/reel2

# %%
# %cd ./scripts/demo/local
# Out:
# /content/sapiens/pose/scripts/demo/local

# %%
# !./keypoints308.sh
# Out:
# Distributing 100 image paths into 1 jobs.
# Traceback (most recent call last):
#   File "/content/sapiens/pose/demo/demo_vis.py", line 14, in <module>
#     import mmcv
# ModuleNotFoundError: No module named 'mmcv'
# /content/sapiens/pose/scripts/demo/local
# Processing complete.
# Results saved to /content/sapiens/pose/output/vis/itw_videos/reel2/sapiens_1b
